# %%
#1. Variables in Python
# - A variable is a **name** that stores a value in memory.
# - No need to declare type explicitly → Python decides automatically.

# ```python
x = 10          # integer
y = 3.14        # float
name = "Alice"  # string
is_active = True  # boolean

# %%
print(x, y, name, is_active)

# %%
import sys

# %%
x = 10
y = 3.14
name = "Alice"
nums = [1, 2, 3]

# %%
print("Type:", type(x), "Size:", sys.getsizeof(x))
print("Type:", type(y), "Size:", sys.getsizeof(y))
print("Type:", type(name), "Size:", sys.getsizeof(name))
print("Type:", type(nums), "Size:", sys.getsizeof(nums))

# %%
age = 18

if age < 13:
    print("Child")
elif age < 20:
    print("Teenager")
else:
    print("Adult")

# %%
for i in range(5):
    print("Iteration:", i)

# %%
count = 0
while count < 5:
    print("Count:", count)
    count += 1

# %%
for i in range(10):
    if i == 5:
        break
    print(i)

# %%
for i in range(10):
    if i % 2 == 0:
        continue
    print(i)   # only odd numbers

# %%
for i in range(5):
    if i == 3:
        pass
    else:
        print(i)

# %%
# Missing colon (:) after if → SyntaxError
if 5 > 2
    print("Yes")

# %%
x = 10
y = 0
# Division by zero → ZeroDivisionError
print(x / y)

# %% [markdown]
# #Problem Statement: Student Grading System
#
# A school wants to create a simple grading system using Python.
#
# The program should ask the user to enter a student’s marks (0–100).
#
# Based on the marks, the program should decide the grade using control statement.

# %% [markdown]
# #Problem Statement: Odd, Even, or Multiple of 5
#
# Write a Python program that takes a number as input and classifies it as:
#
# 1. "Even and Multiple of 5" if the number is even and divisible by 5.
#
# 2. "Even" if the number is even but not divisible by 5.
#
# 3. "Odd" if the number is odd.
#
# ##Requirements:
#
# 1. Use if / elif / else statements.
#
# 2.  Remember that a number is even if divisible by 2.
#
# 3.  A number can be both even and multiple of 5.
